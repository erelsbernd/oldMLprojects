# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
#import warnings
import numpy as np

# %%
auto = pd.read_csv("Automobile_price_data _Raw.csv")
auto.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...    engine-size  \
# 0  convertible          rwd           front        88.6  ...            130
# 1  convertible          rwd           front        88.6  ...            130
# 2    hatchback          rwd           front        94.5  ...            152
# 3        sedan          fwd           front        99.8  ...            109
# 4        sedan          4wd           front        99.4  ...            136
#
# ...

# %% [markdown]
# #### Make histogram of engine size

# %%
plt.hist(auto["engine-size"], alpha=0.5)
# Out:
# (array([  6.,  95.,  46.,  30.,  14.,   7.,   2.,   2.,   0.,   3.]),
#  array([  61. ,   87.5,  114. ,  140.5,  167. ,  193.5,  220. ,  246.5,
#          273. ,  299.5,  326. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# Make a boxplot of engine-size, group by make. Use figsize, fontsize and rot to make sure that
# your chart is readable

# %%
auto.boxplot(column='engine-size', by='make', figsize=(15,10), fontsize=12, rot=45)

# %% [markdown]
# Make a boxplot of price, group by make. It might shows an error, answer in the comment box on what happened and the reason why it’s happening.

# %%
#auto.boxplot(column='price', by='make', figsize=(15,10), fontsize=12, rot=45);

# %% [markdown]
# The above throws an error because price is of type object and not an int

# %%
auto.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %% [markdown]
# #### Redo your step 4 on the auto_clean. Make a boxplot of price, group by make.

# %%
auto_clean = pd.read_csv("auto_clean.csv")
auto_clean.boxplot(column='price', by='make', figsize=(15,10), fontsize=12, rot=45)

# %% [markdown]
# #### Create a seaborn pairplot of your auto_clean to see all the potential correlation between your column(feature).

# %%
sns.pairplot(auto_clean, hue='make');

# %% [markdown]
# #### Create a seaborn pairplot with only selective columns (the columns that look like to have correlation potential) "city-mpg","highway-mpg","curb-weight","make","engine-size","price", "horsepower".

# %%
auto2 = auto_clean.loc[:,["city-mpg","highway-mpg","curb-weight","make","engine-size","price", "horsepower"]]
sns.pairplot(auto2, hue='make')
