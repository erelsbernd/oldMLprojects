# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
#import warnings
import numpy as np

# %%
auto = pd.read_csv("autor2.csv")
auto.head(5)
# Out:
#    symboling  normalized-losses       make fuel-type aspiration num-of-doors  \
# 0          2                121  chevrolet       gas        std          two
# 1          2                137      honda       gas        std          two
# 2          2                137      honda       gas        std          two
# 3          1                101      honda       gas        std          two
# 4          1                 98  chevrolet       gas        std          two
#
#   body-style drive-wheels engine-location  wheel-base  ...    engine-size  \
# 0  hatchback          fwd           front        88.4  ...             61
# 1  hatchback          fwd           front        86.6  ...             92
# 2  hatchback          fwd           front        86.6  ...             92
# 3  hatchback          fwd           front        93.7  ...             79
# 4  hatchback          fwd           front        94.5  ...             90
#
# ...

# %%
auto4 = pd.read_csv("autor2.csv")

# %%
auto["make"]
# Out:
# 0          chevrolet
# 1              honda
# 2              honda
# 3              honda
# 4          chevrolet
# 5              dodge
# 6              dodge
# 7             nissan
# 8              mazda
# 9              mazda
# 10             mazda
# 11         chevrolet
# 12          plymouth
# 13        mitsubishi
# 14            nissan
# 15            nissan
# 16             honda
# 17        mitsubishi
# 18             mazda
# 19             mazda
# 20            nissan
# 21             honda
# 22             dodge
# 23          plymouth
# 24            nissan
# 25            toyota
# 26             dodge
# 27             dodge
# 28          plymouth
# 29        mitsubishi
#            ...
# 129           toyota
# 130           peugot
# 131            volvo
# 132            volvo
# 133            volvo
# 134            volvo
# 135           nissan
# 136            volvo
# 137           nissan
# 138           peugot
# 139           peugot
# 140             audi
# ...

# %%
plt.hist(auto["engine-size"], alpha=0.5)
# Out:
# (array([  2.,  56.,  37.,  26.,  20.,   6.,  10.,   0.,   1.,   1.]),
#  array([  61. ,   80.7,  100.4,  120.1,  139.8,  159.5,  179.2,  198.9,
#          218.6,  238.3,  258. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(auto["city-mpg"], alpha=0.5)
# Out:
# (array([ 11.,  23.,  37.,  33.,  38.,   3.,  11.,   0.,   1.,   2.]),
#  array([ 15. ,  18.4,  21.8,  25.2,  28.6,  32. ,  35.4,  38.8,  42.2,
#          45.6,  49. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(auto["engine-size"], alpha=0.5)
plt.hist(auto["city-mpg"], alpha=0.5)
# Out:
# (array([ 11.,  23.,  37.,  33.,  38.,   3.,  11.,   0.,   1.,   2.]),
#  array([ 15. ,  18.4,  21.8,  25.2,  28.6,  32. ,  35.4,  38.8,  42.2,
#          45.6,  49. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(auto4["price"], alpha = 0.5)
# Out:
# (array([ 62.,  39.,  17.,  14.,  14.,   6.,   2.,   2.,   1.,   2.]),
#  array([  5118. ,   8111.8,  11105.6,  14099.4,  17093.2,  20087. ,
#          23080.8,  26074.6,  29068.4,  32062.2,  35056. ]),
#  <a list of 10 Patch objects>)

# %%
auto2 = auto4.loc[:,["city-mpg","make","horsepower"]]
auto2.head()
auto2.dtypes
sns.pairplot(auto2, hue='make')

# %%
auto.head()
sns.pairplot(auto, hue='make');

# %%
auto.dtypes
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower             int64
# peak-rpm               int64
# city-mpg               int64
# highway-mpg            int64
# price                  int64
# dtype: object

# %%
auto2 = auto.convert_objects(convert_numeric=True)
auto2.dtypes
# Out:
# //anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   if __name__ == '__main__':
# symboling              int64
# normalized-losses      int64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower             int64
# peak-rpm               int64
# city-mpg               int64
# ...

# %%
sns.pairplot(auto,hue='make',size=2.5)
