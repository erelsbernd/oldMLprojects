# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
drinks = pd.read_csv("http://bit.ly/drinksbycountry")
drinks.head(200)
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan              0                0              0
# 1                 Albania             89              132             54
# 2                 Algeria             25                0             14
# 3                 Andorra            245              138            312
# 4                  Angola            217               57             45
# 5       Antigua & Barbuda            102              128             45
# 6               Argentina            193               25            221
# 7                 Armenia             21              179             11
# 8               Australia            261               72            212
# 9                 Austria            279               75            191
# 10             Azerbaijan             21               46              5
# 11                Bahamas            122              176             51
# ...

# %%
drinks['country']
drinks.groupby('country').sum()
# Out:
#                       beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan                       0                0              0
# Albania                          89              132             54
# Algeria                          25                0             14
# Andorra                         245              138            312
# Angola                          217               57             45
# Antigua & Barbuda               102              128             45
# Argentina                       193               25            221
# Armenia                          21              179             11
# Australia                       261               72            212
# Austria                         279               75            191
# Azerbaijan                       21               46              5
# Bahamas                         122              176             51
# Bahrain                          42               63              7
# ...

# %%
type(drinks['country'])
# Out:
# pandas.core.series.Series

# %%
type(drinks)
# Out:
# pandas.core.frame.DataFrame

# %%
drinks[['country', 'beer_servings', 'continent']]
# Out:
#                   country  beer_servings      continent
# 0             Afghanistan              0           Asia
# 1                 Albania             89         Europe
# 2                 Algeria             25         Africa
# 3                 Andorra            245         Europe
# 4                  Angola            217         Africa
# 5       Antigua & Barbuda            102  North America
# 6               Argentina            193  South America
# 7                 Armenia             21         Europe
# 8               Australia            261        Oceania
# 9                 Austria            279         Europe
# 10             Azerbaijan             21         Europe
# 11                Bahamas            122  North America
# 12                Bahrain             42           Asia
# 13             Bangladesh              0           Asia
# 14               Barbados            143  North America
# 15                Belarus            142         Europe
# ...

# %%
#drinks = ["beer_servings"]
#.groupby('continent').sum()

# %%
type(drinks)
# Out:
# pandas.core.frame.DataFrame

# %%
drinks[['country','beer_servings','continent']]
# Out:
#                   country  beer_servings      continent
# 0             Afghanistan              0           Asia
# 1                 Albania             89         Europe
# 2                 Algeria             25         Africa
# 3                 Andorra            245         Europe
# 4                  Angola            217         Africa
# 5       Antigua & Barbuda            102  North America
# 6               Argentina            193  South America
# 7                 Armenia             21         Europe
# 8               Australia            261        Oceania
# 9                 Austria            279         Europe
# 10             Azerbaijan             21         Europe
# 11                Bahamas            122  North America
# 12                Bahrain             42           Asia
# 13             Bangladesh              0           Asia
# 14               Barbados            143  North America
# 15                Belarus            142         Europe
# ...

# %%
type(drinks['country'])
# Out:
# pandas.core.series.Series

# %%
drinks[drinks.continent=='Asia']
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan              0                0              0
# 12                Bahrain             42               63              7
# 13             Bangladesh              0                0              0
# 19                 Bhutan             23                0              0
# 24                 Brunei             31                2              1
# 30               Cambodia             57               65              1
# 36                  China             79              192              8
# 46            North Korea              0                0              0
# 77                  India              9              114              0
# 78              Indonesia              5                1              0
# 79                   Iran              0                0              0
# 80                   Iraq              9                3              0
# ...

# %%
beer = drinks[['country','beer_servings','continent']]
beer.head(50)
# Out:
#                      country  beer_servings      continent
# 0                Afghanistan              0           Asia
# 1                    Albania             89         Europe
# 2                    Algeria             25         Africa
# 3                    Andorra            245         Europe
# 4                     Angola            217         Africa
# 5          Antigua & Barbuda            102  North America
# 6                  Argentina            193  South America
# 7                    Armenia             21         Europe
# 8                  Australia            261        Oceania
# 9                    Austria            279         Europe
# 10                Azerbaijan             21         Europe
# 11                   Bahamas            122  North America
# 12                   Bahrain             42           Asia
# 13                Bangladesh              0           Asia
# 14                  Barbados            143  North America
# ...

# %%
drinks.groupby("continent").plot(kind='bar')
# Out:
# continent
# Africa           Axes(0.125,0.125;0.775x0.775)
# Asia             Axes(0.125,0.125;0.775x0.775)
# Europe           Axes(0.125,0.125;0.775x0.775)
# North America    Axes(0.125,0.125;0.775x0.775)
# Oceania          Axes(0.125,0.125;0.775x0.775)
# South America    Axes(0.125,0.125;0.775x0.775)
# dtype: object

# %%
drinks.groupby("continent").mean().plot(kind='bar')

# %%
beer.groupby("continent").head()
# Out:
#                country  beer_servings      continent
# 0          Afghanistan              0           Asia
# 1              Albania             89         Europe
# 2              Algeria             25         Africa
# 3              Andorra            245         Europe
# 4               Angola            217         Africa
# 5    Antigua & Barbuda            102  North America
# 6            Argentina            193  South America
# 7              Armenia             21         Europe
# 8            Australia            261        Oceania
# 9              Austria            279         Europe
# 10          Azerbaijan             21         Europe
# 11             Bahamas            122  North America
# 12             Bahrain             42           Asia
# 13          Bangladesh              0           Asia
# 14            Barbados            143  North America
# 17              Belize            263  North America
# 18               Benin             34         Africa
# ...

# %%
beer_Asia = beer[beer.continent=="Asia"].beer_servings #groupby("continent")
beer_NorthAmerica = beer[beer.continent=="North America"].beer_servings
beer_Europe = beer[beer.continent=="Europe"].beer_servings
beer_Africa = beer[beer.continent=="Africa"].beer_servings
beer_SouthAmerica = beer[beer.continent=="South America"].beer_servings
beer_Oceania = beer[beer.continent=="Oceania"].beer_servings

fig = plt.figure(figsize=(14,8))
fig.suptitle('LAS350A Lab 6', fontsize=14, fontweight='bold')
ax = fig.add_subplot(111)
ax.boxplot((beer_Asia, beer_NorthAmerica, beer_Europe, beer_Africa, beer_SouthAmerica, beer_Oceania))
ax.set_title('Beer_Servings_by_Continent')
ax.set_xlabel('Continent')
ax.set_ylabel('Number_Servings')
plt.xticks([1,2,3,4,5,6],['Asia', 'North America','Europe','Africa', 'South America', 'Oceania'])
# Out:
# ([<matplotlib.axis.XTick at 0x119fadf60>,
# ...
#  <a list of 6 Text xticklabel objects>)
