# %%
from bokeh.charts import Bar, output_file, show
from bokeh.charts import BoxPlot, output_file, show
from bokeh.charts import Scatter, output_file, show
import pandas as pd
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
#import warnings
import numpy as np

# %%
auto = pd.read_csv("autor2.csv")
auto.head(5)
# Out:
#    symboling  normalized-losses       make fuel-type aspiration num-of-doors  \
# 0          2                121  chevrolet       gas        std          two
# 1          2                137      honda       gas        std          two
# 2          2                137      honda       gas        std          two
# 3          1                101      honda       gas        std          two
# 4          1                 98  chevrolet       gas        std          two
#
#   body-style drive-wheels engine-location  wheel-base  ...    engine-size  \
# 0  hatchback          fwd           front        88.4  ...             61
# 1  hatchback          fwd           front        86.6  ...             92
# 2  hatchback          fwd           front        86.6  ...             92
# 3  hatchback          fwd           front        93.7  ...             79
# 4  hatchback          fwd           front        94.5  ...             90
#
# ...

# %%
auto.dtypes
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower             int64
# peak-rpm               int64
# city-mpg               int64
# highway-mpg            int64
# price                  int64
# dtype: object

# %%
p = BoxPlot(auto, values = 'price', label = ['make','engine-size'],title="Engine Size by make", color='make', plot_width=1000, plot_height=800)
output_file("boxplot_es.html")
show(p)

# %% [markdown]
# #### Boxplot of Price Summary
# (grouped by make,body-style)

# %%
p = BoxPlot(auto, values = 'price', label = ['make','body-style'], title="Body Style by make",color='make', plot_width=1000, plot_height=800)
output_file("boxplot_bs.html")
show(p)

# %% [markdown]
# Make a scatter plot title="LAS350A - Lab 10: Price vs City-mpg (shaded by Make, maker by Bodystyle)"
# with tooltips Price,Make,Bodystyle,Citympg according to the following sample:

# %%
auto['bodystyle'] = auto['body-style']
auto['citympg'] = auto['city-mpg']
auto.head()
# Out:
#    symboling  normalized-losses       make fuel-type aspiration num-of-doors  \
# 0          2                121  chevrolet       gas        std          two
# 1          2                137      honda       gas        std          two
# 2          2                137      honda       gas        std          two
# 3          1                101      honda       gas        std          two
# 4          1                 98  chevrolet       gas        std          two
#
#   body-style drive-wheels engine-location  wheel-base   ...     bore  stroke  \
# 0  hatchback          fwd           front        88.4   ...     2.91    3.03
# 1  hatchback          fwd           front        86.6   ...     2.91    3.41
# 2  hatchback          fwd           front        86.6   ...     2.91    3.41
# 3  hatchback          fwd           front        93.7   ...     2.91    3.07
# 4  hatchback          fwd           front        94.5   ...     3.03    3.11
#
# ...

# %%
auto['bodystyle'] = auto['body-style']
auto['citympg'] = auto['city-mpg']
auto.head()


tooltips=[
    ('Price', '@price'),
    ('Make','@make'),
    ('Body Style', '@bodystyle'),
    ('City MPG', '@citympg')
]

p = Scatter(auto, x='city-mpg', y= 'price', color='make', marker = 'body-style', title="Price vs City-mpg", plot_width=1000, plot_height=800,\
 xlabel='city-mpg', ylabel='price', tooltips= tooltips)


output_file("scatter_pm.html")
show(p)

# %% [markdown]
# ##### Find the most efficient city-mpg (highest city-mpg with the lowest price) sedan.
# Nisan sedan citympg = 45, price = 7099

# %%
#ignore everything below

# %%
p = BoxPlot(auto, values = 'price', label = 'make', title="Body Style by make",color='make', plot_width=1000, plot_height=800)
output_file("boxplot_pm.html")
show(p)


p = Scatter(auto, x='make', y= 'price', color='make', marker = 'body-style', title="Body Style by make", plot_width=1000, plot_height=800,\
           xlabel='make', ylabel='price')
output_file("scatter_bs.html")
show(p)
